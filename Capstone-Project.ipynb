# %% [markdown]
# # 1. Introduction

# %% [markdown]
# 1a. Business Problem
#
# In this project, we will find an optimal location for opening up a Taiwanses signature beef noodle restaurant in Taipei. Taipei is a small city with a dense population that has an unique culture for food. This specific dish, Taiwanese beef noodles, is widely popular by both local residents and foreign tourists, hence the high competitiveness amongst restaurants. In order to locate a situable spot, we will be looking for two criterias. First,  there should be as little beef noodle selling restaurants as possible near by. Second, it should be near a tourist spot or centers to raise the accessibility of the store.

# %% [markdown]
# 1b. Interest
#
# This solution is obviously advantagous for anyone that plans to open up a beef noddle restuarant in Taipei. However, this model can also be refered as a template for different types of shop owners to utilize in choosing an optimal location in Taipei.

# %% [markdown]
# # 2. Data Description

# %% [markdown]
# a) We will be obtaining the data for our first criteria through FourSquare API (# of restaurants and their type and location)
#
# b) We will then obtain the coordinates for popular centers/spots with Google Maps API geocoding

# %% [markdown]
# (insert data)

# %% [markdown]
# # 3. Methodology

# %% [markdown]
# -limitations
# (pick a tourist center)

# %% [markdown]
# # 4. Results

# %% [markdown]
# 4a. Results Analysis
#
# 4b. Observation Discussions

# %% [markdown]
# # 5. Conclusion

# %% [markdown]
# conclude (purpose, summary, decision)
